# %% [markdown]
# ### Data Description
# - The data we have is about football players and the game FIFA 20. It includes details like players' names, ages, nationalities, and their abilities in the game, such as shooting, passing, and speed. We also have information about the clubs they play for, their market values, and other statistics.
# - The FIFA 20 dataset consists of 18,278 rows (entries) and 104 columns(categories of information), it contains detailed information about football players, their attributes, personal details, and various in-game statistics.

# %% [markdown]
# ###  Business case
# - The goal of this data analysis is to gain insights into player performance, market values, and team dynamics.
# - The FIFA 20 Dataset Analysis project aims to leverage the rich dataset to gain valuable insights into player performance and team dynamics.
# - The outcomes of this analysis will be relevant for gamers, football enthusiasts, and clubs, contributing to better team-building strategies and enhancing the gaming experience. - - Additionally, the project can highlight the importance of data analysis in sports and serve as a foundation for future research in the field of football analytics..
# - It allows for in-depth exploration of player attributes and performances, enabling various data analysis and machine learning tasks.
# - some key attributes being compared or analysied in the dataset are skill ratings,personal information, club and team information, player attributes,playing position, market value, goalkeeping attributes etc.
# - Understanding player attributes and their market values can help gamers select the best players for their teams and enhance team performance in the game.
# - Football clubs can use insights from player attributes and performance statistics to identify potential talents and make informed decisions during player recruitment in real life.
# - Insights into player attributes and market values can help gamers create well-balanced teams with higher chances of success in the game.
# - Football clubs can use the analysis to scout potential talents and understand the strengths and weaknesses of players in their squad.
# - Identifying popular player positions and formations can lead to better tactical decisions during both virtual and real-world matches.
# - In summary the project will enhance the understanding of football analytics and showcase the potential of data-driven decision-making in sports and gaming.

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# load the dataset
fifa=pd.read_csv('players_20.csv')

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# displaying the dataset
pd.set_option('display.max_columns',None)
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 14.5+ MB

# %%
# numerical columns
nc=fifa .describe().columns
print('total count:',len(nc))
nc
# Out:
# total count: 61
# Index(['sofifa_id', 'age', 'height_cm', 'weight_kg', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'international_reputation', 'weak_foot',
#        'skill_moves', 'release_clause_eur', 'team_jersey_number',
#        'contract_valid_until', 'nation_jersey_number', 'pace', 'shooting',
#        'passing', 'dribbling', 'defending', 'physic', 'gk_diving',
#        'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
# ...

# %%
# categorical columns
cc=fifa.describe(include='O').columns
print('total count:',len(cc))
cc
# Out:
# total count: 43
# Index(['player_url', 'short_name', 'long_name', 'dob', 'nationality', 'club',
#        'player_positions', 'preferred_foot', 'work_rate', 'body_type',
#        'real_face', 'player_tags', 'team_position', 'loaned_from', 'joined',
#        'nation_position', 'player_traits', 'ls', 'st', 'rs', 'lw', 'lf', 'cf',
#        'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb',
#        'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object')

# %% [markdown]
# ### Univarient Data Analysis with Sweetviz
# - we can use Sweetviz to generate visualizations and statistics for each variable in the dataset individually.

# %%
import sweetviz as sv
sweet=sv.analyze(fifa)
sweet.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# Observations
# - The age varriable is normally distributed with average 25.3, most of the value ranging between 20 and 30 with age 22 as most frequency of 7.9%. The age value ranges from 16 to 42.
# - Most of the players are from the country EnglandGermany,Spain,France,Argentina,Brazil and Italy.
# - The maximum score of overall rating is 94 and minimum is 48.0 with the average of 66.2 with most ranging from 65 to 75.
# - The maximum score of player potential is 95.0 and minimum score of potential is 49.0
# - 76% players are right footed and 24% are left footed.
# - More than 50% of players are recieving wages from 1000 to 3000 euros but the average is 9000 euros which clearly shows that the wages are not normally distributed, we have players earning as high as 565k euros
# - 92% players have 1 star international reputation and only six players are with 5 star reputation.
# - A week foot is rated between 1 to 5,most of week foot player rating is 3.
# - The majority have 2 skill moves, making it the most common skill level. Additionally, approximately 36% of the players possess 3 skill moves, while only 11% have a skill level of 1.
# - Around 54% of players have a medium/medium work rate and 18% of players have a work rate that is considered high/medium.
# - 59% player body type is normal,36% player body type is lean.
# - 89% player face is not real and remaining 11% face is real in game.
# - The average release clause is 4.7 million euros with maximum release clause of 195,8M.
#
# These are some insights taken from the sweetviz graph, the histogram plot reveals the distribution of player attributes like pace, shooting, passing, defending, dribbling, and physic, providing insights into their specific skill levels.Additionally,it illustrates how players are distributed across different positions on the field, such as strikers, midfielders, defenders, and goalkeepers.

# %% [markdown]
# ### Bivarient and Multivarient Data Analysis

# %% [markdown]
# ### Age Impact on Football Player Performance

# %%
column=['overall','potential','value_eur','pace','dribbling','movement_reactions','power_stamina','mentality_vision','power_jumping']
plt.figure(figsize=(17,12))
plt.suptitle('Age Impact on Football Player Performance',fontsize=16)
i=1
for j in column:
  plt.subplot(3,3,i)
  sns.lineplot(x=fifa.age,y=fifa[j])
  i+=1
plt.show()

# %% [markdown]
# Age vs Overall:
# - We observe that players' ratings generally increase with age until they reach 35 years old.
# - After this point, we notice a zigzag pattern in the overall ratings, indicating fluctuations in performance as players get older.
#
# Age vs Potential:
# - The graph clearly indicates that as player's age increases, their potential decreases.
# - This observation highlights a strong correlation between age and potential, suggesting that a player's potential is significantly influenced by their age.
# - Younger players tend to have higher potential ratings, while older players exhibit lower potential ratings in the dataset.
#
# Age vs value_eur:
# - Players who are young or old generally have lower market values, while those within the age range of 22 to 32 tend to have higher market values.
# - So typically the players market value increases gradually from young age and reaches peak between 25 and 30 then gradually goes down.
#
# Age vs Pace:
# - As expected the pace decreases as age increase, two are strongly negatively correlated.
#
# Age vs Dribbling:
# - The relationship between age and dribbling ability forms a parabolic curve, implying that player's dribbling skills tend to improve as they gain experience and reach a certain peak during their prime years, after which it gradually starts to decline with age.
#
# Age vs Movement reactions:
# - As players' age increases, their movement reactions also tend to increase.
# - The positive correlation between age and movement reactions signifies the impact of experience and maturity on a player's ability to read the game and respond quickly to changes in the match conditions, which is an important attribute for the players.
#
# Age vs Power stamina:
# - Stamina and age exhibit a parabolic relationship; however, beyond the age of 35, there is a sharp decline in stamina levels.
#
# Age vs Mentality vision:
# - As players gain more playing time and exposure to different scenarios on the field, their ability to read the game, anticipate moves, and make better strategic decisions improves.
#
# Age vs Power jumping:
# - Contrary to the general expectation that power jumping tends to decrease with age due to physical decline and decreased athletic ability, the dataset reveals an interesting observation that power jumping actually increases with age.

# %% [markdown]
# ### Performance of Left footed players vs Right footed players

# %%
column=['value_eur','skill_curve','dribbling','passing','skill_ball_control','skill_moves','shooting','attacking_crossing','attacking_finishing']
plt.figure(figsize=(17,12))
plt.suptitle('Performance of Left footed players vs Right footed players',fontsize=16)
i=1
for j in column:
  plt.subplot(3,3,i)
  sns.barplot(x=fifa.preferred_foot,y=fifa[j])
  i+=1
plt.show()

# %% [markdown]
# Based on the graph generated, which compares various attributes for left-footed and right-footed players, we can draw the following conclusions:
#
# - Right-footed players tend to have a higher shooting attribute compared to left-footed players.
# - This indicates that right-footed players, on average, might be more effective in shooting during gameplay.
# - Skill Curve, Dribbling, Passing, Skill Ball Control, and Skill Moves: For all these attributes, left-footed players outperform right-footed players.
# - This suggests that left-footed players generally exhibit better skills in areas related to ball control, dribbling, passing, and overall skill moves.
# - Overall, based on the attributes considered in the graph, left-footed players seem to have an advantage over right-footed players in several key skill areas like dribbling, passing, and ball control.
# - However, right-footed players tend to excel more in shooting.

# %% [markdown]
# ### Top 10 Countries and Clubs with the Highest Average Player Salary

# %%
i=['nationality','club']
for i in i:
  top_salary = fifa.groupby([i], dropna=True)['wage_eur'].mean().round(2).sort_values(ascending=False)[:10]
  plt.figure(figsize=(15,5))
  sns.barplot(x=top_salary.index, y=top_salary.values)
  plt.ylabel("Avg. Salary in Euro")
  plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Obervations for nationalities:
#
# - The analysis of the FIFA 20 dataset reveals interesting findings about player salaries.
# - Surprisingly, the Dominican Republic tops the list with the highest average salary of 38,250 Euros, followed by Armenia and Gabon.
# - This highlights that players from less prominent footballing nations can still command significant wages. Additionally, the presence of traditional football powerhouses like Algeria, Syria, and Croatia in the top five list
# - Brazil, one of the world's most renowned football nations, also ranks in the top 10, indicating the high value placed on Brazilian players' skillsets in the FIFA 20 game.
#
# Observation for Clubs:
# - Real Madrid and FC Barcelona hold the top two positions with the highest average player salaries, standing at 162,242 Euros and 150,000 Euros, respectively. It showcases the financial strength and allure of these Spanish giants in attracting top talent.
# - The provided data reveals the financial ability of top football clubs like Manchester City, Juventus, and FC Bayern München, with significant average player salaries, showcasing their ability to build strong and well-paid squads, enhancing their prominence in the football world.
# - we also have premier league giant clubs like man_united, chelsea, liverpool and tottenham hotspur in the list

# %% [markdown]
# ### Task 3
# 1.Rank ordered list of top 10 countries with most players

# %%
top_countries = fifa['nationality'].value_counts().nlargest(10)
print(top_countries)
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.bar(top_countries.index, top_countries.values)
plt.xlabel('Country')
plt.ylabel('Number of Players')
plt.title('Top 10 Countries with the Most Players in FIFA 20')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:
# - England has the highest number of players (1667) in the FIFA 20 dataset, indicating a strong presence of English players in the game.
# - Following England, Germany (1216) and Spain (1035) are the second and third countries with a significant number of players, showcasing their footballing strength and popularity.
# - Traditional football powerhouses like France (984) and Argentina (886) are among the top five countries.
# - Brazil (824) and Italy (732) also have a notable presence in the FIFA 20 dataset, reflecting their rich footballing history and legacy.
# - Notably, Japan (453) and the Netherlands (416) secure their spots in the top 10, demonstrating the growing influence and popularity of football in these nations.

# %% [markdown]
# 2. Distribution of Overall Rating vs. Age of Players

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='age', y='overall', data=fifa, ci=None)
plt.xlabel('Age')
plt.ylabel('Overall Rating')
plt.title('Overall Rating vs. Age of Players')
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:
# -  The overall rating vs. age plot showcases an inverted U-shaped trend, indicating that young players start with relatively lower overall ratings, then experience significant improvement as they gain experience.
# -  However, after reaching a peak point, the overall ratings tend to stabilize or decline slightly as players age further.
# - The plot suggests that players generally experience the most substantial improvement in their overall ratings during their late-20s to early-30s.
# - This age range represents the prime years of player development, where players' skills, physical attributes, and game understanding are at their peak.
# - As we can see that after the age of 35 the overall rating of players stops improving and beyond this point, the curve takes on a zigzag pattern, indicating that not all players continue to improve.Instead, the improvement varies depending on the individual players.

# %% [markdown]
# 3. Offensive player with highest wages

# %%
offensive_positions = ['ST', 'RW', 'LW']

# Filter the DataFrame to include only the offensive positions (ST, RW, LW)
offensive_players = fifa[fifa['player_positions'].isin(offensive_positions)]

average_wages = offensive_players.groupby('player_positions')['wage_eur'].mean().round(2).sort_values(ascending=False)

print(average_wages)
# Out:
# player_positions
# ST    10256.50
# LW     9681.82
# RW     6208.79
# Name: wage_eur, dtype: float64

# %%
ax=sns.barplot(y=average_wages.values,x=average_wages.index)
plt.xlabel('Player Positions')
plt.ylabel('Average Wages (EUR)')
plt.title('Average Wages for Offensive Positions')
plt.show()

# %% [markdown]
# Observation:
# - Left Wingers (LW) have the highest average wage of approximately 38,529.41 Euros, suggesting that players in this position are highly valued and well compensated.
# - Strikers (ST) follow closely behind with an average wage of around 31,903.61 Euros, indicating their crucial role in scoring goals.
# - Right Wingers (RW) have an average wage of about 29,909.09 Euros, slightly lower than LW and ST positions.
# - The difference in salaries between players in the left-wing (LW) and right-wing (RW) positions can be attributed to factors such as individual player performance, playing approach, and the market's demand for players in each specific position.
# - The data suggests that attacking positions, such as LW, ST, and RW, generally command higher wages compared to other positions, highlighting the significance of offensive skills and goal-scoring abilities in football.

# %% [markdown]
# ### Data Preprocessing

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# load the dataset
fifa=pd.read_csv('players_20.csv')
# displaying the dataset
pd.set_option('display.max_columns',None)

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
# displaying all the columns in the fifa dataset
column=[]
for columns in fifa:
  column.append(columns)
print('total count:',len(column))
column
# Out:
# total count: 104
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
# ...

# %% [markdown]
# ### Dropping unimportant features
# - Since we are clustering the players based on football attributes and skillset ,we can omit features that are not relevant to this specific analysis.
# - The selection of relevant attributes (such as pace, shooting, passing, dribbling) will be crucial for accurate clustering of players based on their football abilities.
#
# - Here are some columns that can be considered for dropping:
#
# - 1.'sofifa_id': This column is a unique identifier and does not provide any meaningful information about player skills.
#
# - 2.'player_url': This column contains URLs and is not relevant to player skills.
#
# - 3.'short_name' and 'long_name': These columns contain player names, which are not directly related to their skills.
#
# - 4.'dob', 'nationality', 'club': While these columns provide descriptive information about the players, they are not specific to their skills and can be dropped.
#
# - 5.'real_face': This column indicates whether the player has a real face in the game, which is not relevant to their skills.
#
# - 6.'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until', 'nation_jersey_number': These columns contain specific player information in a given team or nation context but may not be directly related to skill clustering.
#
# - 7.'release_clause_eur': This column represents the player's release clause value and may not directly affect their skillset.

# %%
columns_to_drop = [
    'sofifa_id', 'player_url', 'short_name', 'long_name', 'dob',
    'nationality', 'club', 'real_face', 'team_jersey_number',
    'loaned_from', 'joined', 'contract_valid_until', 'nation_jersey_number']

fifa.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# ### Data Cleaning
# - Feature transformation is a technique used to make the original features (variables) of a dataset to make them more suitable for analysis.
# - Here the player_positions and work_rate features have more than one option in each row so we can transform this features by taking only the first one (eg for ST,LW we can take only ST)
# - for features like ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw', etc , we have values in '89+2' we can transform it to '91'

# %%
fifa.player_positions=fifa.player_positions.str.split(',').str[0]

# %%
fifa['work_rate'] = fifa['work_rate'].str.split('/').str[0]

# %%
columns_to_transform = ['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb']
for i in columns_to_transform:
    fifa[i] = fifa[i].str.split('+').str[0]

# %% [markdown]
# ### Finding missing values

# %%
for columns in fifa:
    if fifa[columns].isnull().sum()>0:
        print('Column name:'+str(columns)+ ",                 Total Null:" + str(fifa[columns].isnull().sum()) + ",               Percentage:" + str(100*fifa[columns].isnull().mean().round(3)))
# Out:
# Column name:release_clause_eur,                 Total Null:1298,               Percentage:7.1
# Column name:player_tags,                 Total Null:16779,               Percentage:91.8
# Column name:team_position,                 Total Null:240,               Percentage:1.3
# Column name:nation_position,                 Total Null:17152,               Percentage:93.8
# Column name:pace,                 Total Null:2036,               Percentage:11.1
# Column name:shooting,                 Total Null:2036,               Percentage:11.1
# Column name:passing,                 Total Null:2036,               Percentage:11.1
# Column name:dribbling,                 Total Null:2036,               Percentage:11.1
# Column name:defending,                 Total Null:2036,               Percentage:11.1
# Column name:physic,                 Total Null:2036,               Percentage:11.1
# Column name:gk_diving,                 Total Null:16242,               Percentage:88.9
# ...

# %% [markdown]
# Dropping columns with high missing valuse(>50%)
# - Here player tags , national position, player traits have high missing values so can be dropped.
# -  Dropping columns with a significant number of missing values is a common approach when those columns don't provide critical information for the analysis.
# - Imputation might not be appropriate or beneficial.
# - Features like gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning' are important features for clustering.
# - But can be dropped because of two reasons
#  -  88% null values
#  -  These values are explained in other features like goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes'.

# %%
fifa.drop(columns=['player_tags','nation_position','player_traits','gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning'],inplace=True)

# %% [markdown]
# - The "team_position" column can be safely dropped from the analysis since it contains more than 50% of its values as "substitute" and "reserve."
# - These labels do not accurately represent the players' original playing positions.
# - Instead, we can rely on the "player_positions" column, which provides the players' precise positions on the field, ensuring a more accurate representation of their roles in the game.

# %%
fifa.drop(columns='team_position',inplace=True)

# %%
fifa.head()
# Out:
#    age  height_cm  weight_kg  overall  potential  value_eur  wage_eur  \
# 0   32        170         72       94         94   95500000    565000
# 1   34        187         83       93         93   58500000    405000
# 2   27        175         68       92         92  105500000    290000
# 3   26        188         87       91         93   77500000    125000
# 4   28        175         74       91         91   90000000    470000
#
#   player_positions preferred_foot  international_reputation  weak_foot  \
# 0               RW           Left                         5          4
# 1               ST          Right                         5          4
# 2               LW          Right                         5          5
# 3               GK          Right                         3          3
# 4               LW          Right                         4          4
#
#    skill_moves work_rate   body_type  release_clause_eur  pace  shooting  \
# ...

# %% [markdown]
# ### Handling missing values
# - Based on domain knowledge, it is clear that the 2036 null values in the dataset correspond to the attributes related to goalkeepers' information.
# - Since goalkeepers typically have lower values for certain attributes compared to other players.
# - We can confidently replace these NaN values with the minimum value present in each respective feature.

# %%
c=['pace',
 'shooting',
 'passing',
 'dribbling',
 'defending',
 'physic']
for i in c:
    fifa.loc[fifa[i].isnull()==True,i]=fifa[i].min()

# %%
c=['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb']
for i in c:
    
    fifa.loc[fifa[i].isnull()==True,i]=100
    fifa[i]=fifa[i].astype('int32')
    fifa[i].replace(100,fifa[i].min(),inplace=True)

# %%
sns.histplot(fifa.release_clause_eur,kde=True)
# Out:
# <AxesSubplot:xlabel='release_clause_eur', ylabel='Count'>

# %%
# Impute missing value using median because distribution is not normal
fifa.loc[fifa['release_clause_eur'].isnull()==True,'release_clause_eur']=fifa['release_clause_eur'].median()

# %%
fifa.head()
# Out:
#    age  height_cm  weight_kg  overall  potential  value_eur  wage_eur  \
# 0   32        170         72       94         94   95500000    565000
# 1   34        187         83       93         93   58500000    405000
# 2   27        175         68       92         92  105500000    290000
# 3   26        188         87       91         93   77500000    125000
# 4   28        175         74       91         91   90000000    470000
#
#   player_positions preferred_foot  international_reputation  weak_foot  \
# 0               RW           Left                         5          4
# 1               ST          Right                         5          4
# 2               LW          Right                         5          5
# 3               GK          Right                         3          3
# 4               LW          Right                         4          4
#
#    skill_moves work_rate   body_type  release_clause_eur  pace  shooting  \
# ...

# %%
pd.set_option('display.max_rows', None)
fifa.isnull().any()
# Out:
# age                           False
# height_cm                     False
# weight_kg                     False
# overall                       False
# potential                     False
# value_eur                     False
# wage_eur                      False
# player_positions              False
# preferred_foot                False
# international_reputation      False
# weak_foot                     False
# skill_moves                   False
# work_rate                     False
# body_type                     False
# release_clause_eur            False
# pace                          False
# shooting                      False
# passing                       False
# dribbling                     False
# defending                     False
# physic                        False
# attacking_crossing            False
# attacking_finishing           False
# attacking_heading_accuracy    False
# attacking_short_passing       False
# attacking_volleys             False
# ...

# %% [markdown]
# ### Feature Engineering

# %%
fifa.body_type.value_counts()
# Out:
# Normal                 10750
# Lean                    6505
# Stocky                  1016
# Messi                      1
# C. Ronaldo                 1
# Neymar                     1
# PLAYER_BODY_TYPE_25        1
# Courtois                   1
# Shaqiri                    1
# Akinfenwa                  1
# Name: body_type, dtype: int64

# %%
def body_type_player(df):
    if (df['body_type'] == 'Normal'):
        return 'Normal'
    elif (df['body_type'] == 'Lean'):
        return 'Lean'
    elif (df['body_type'] == 'Stocky'):
        return 'Stocky'
    else:
        return 'Normal'

fifa['body_type'] = fifa.apply(body_type_player, axis=1)

# %% [markdown]
# ### Categorical Encoding
# - There are different techniques to convert categorical data to numeric such as: label encoding, dummy encoding, one hot encoding, frequency encoding, target guided ordinal encoding, mean encoding, etc.
# - Here, we have used manual label encoding.

# %%
fifa.player_positions.value_counts()
# Out:
# CB     3162
# ST     2582
# CM     2193
# GK     2036
# CDM    1424
# RB     1314
# LB     1303
# CAM    1146
# RM     1050
# LM     1049
# LW      378
# RW      369
# CF      113
# LWB      90
# RWB      69
# Name: player_positions, dtype: int64

# %%
fifa.player_positions = fifa.player_positions.map({'GK':14,'CB':13,'RB':12,'LB':11,
                                            'RWB':10,'LWB':9,'CDM':8,'CM':7,'RM':6,'LM':5,'CAM':4,'RW':3,'LW':2,
                                            'ST':1,'CF':0})

# %%
fifa.preferred_foot.value_counts()
# Out:
# Right    13960
# Left      4318
# Name: preferred_foot, dtype: int64

# %%
fifa['preferred_foot'] = fifa['preferred_foot'].map({'Left':0, 'Right':1})

# %%
fifa.work_rate.value_counts()
# Out:
# Medium    12479
# High       4886
# Low         913
# Name: work_rate, dtype: int64

# %% [markdown]
# - Manually label encoding work_rate and body_type because they are ordinal data

# %%
fifa['work_rate'] = fifa['work_rate'].map({'Low':0, 'Medium':1, 'High':2})

# %%
fifa.body_type.value_counts()
# Out:
# Normal    10757
# Lean       6505
# Stocky     1016
# Name: body_type, dtype: int64

# %%
fifa['body_type'] = fifa['body_type'].map({'Normal':1, 'Lean':2, 'Stocky':3,})

# %%
for columns in fifa:
    fifa[columns]=fifa[columns].astype('int32')

# %%
fifa['Attackers'] = (fifa['lf'] + fifa['cf'] + fifa['rf'] + fifa['ls'] + fifa['st'] + fifa['rs'])/6
fifa['Midfielders'] = (fifa['lam'] + fifa['cam'] + fifa['ram'] + fifa['ldm'] + fifa['cdm'] + fifa['rdm'] +
                    fifa['lcm'] + fifa['cm'] + fifa['rcm'] + fifa['lm'] + fifa['rm'] + fifa['rw'] + fifa['lw'])/13
fifa['Defenders'] = (fifa['lb'] + fifa['rb'] + fifa['cb'] + fifa['lcb'] + fifa['rcb'] + fifa['lwb'] + fifa['rwb'])/7

# %%
fifa.drop(['lf', 'cf', 'rf', 'ls', 'st', 'rs', 'lam', 'cam', 'ram', 'ldm', 'cdm', 'rdm', 'lcm', 'cm', 'rcm', 'lm', 'rm', 'rw',
         'lw', 'lb', 'rb', 'cb', 'lcb', 'rcb', 'lwb', 'rwb'], axis=1, inplace=True)

# %% [markdown]
# ### OUTLIER HANDLING
# - Important features like 'age,' 'height_cm,' 'weight_kg', 'value_eur,' 'wage_eur,' and 'release_clause_eur' are continuous and need outlier handling because they can have extreme values that might skew the clustering process.
# - Other features like 'shooting,' 'dribbling,' etc., have values in the range of 0 to 100, representing specific skills, and do not require outlier treatment as they are already bounded within a meaningful range.
# - Outlier handling for continuous features involves identifying and transforming extreme values to ensure a more robust and accurate clustering of football players based on their skill attributes.

# %%
 Data= ['age','height_cm','weight_kg','value_eur','wage_eur','release_clause_eur']

plt.figure(figsize=(20,25)) # defining canvas size
n = 1 

for i in Data: 
    if n<=9:    # set the limit
        plt.subplot(3,3,n) 
        sns.boxplot(x=fifa[i]) # Plotting box plots 
        plt.xlabel(i,fontsize=20)  # assigning name to x-axis and font size is 20
    n+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# ##### CHECKING THE DISTRIBUTION BEFORE HANDLE THE OUTLIER

# %%
Data= ['age','height_cm','weight_kg','value_eur','wage_eur','release_clause_eur']

plt.figure(figsize=(20,25)) # defining canvas size
n = 1 # counter

for i in Data: # iteration of columns / acessing the columns from  dataset 
    if n<=9:    # set the limit
        plt.subplot(3,3,n)
        sns.distplot(x=fifa[i]) # Plotting box plots 
        plt.xlabel(i,fontsize=20)  # assigning name to x-axis and font size is 20
    n+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# - Here age,height_cm,weight_kg,overall,potential follows a normal distribution so we are empherical rule and remaining feature we use iqr

# %% [markdown]
# ##### EMPHERICAL RULE OR 3 STANDARD DEVIATION RULE TO DETECT THE OUTLIER
# - For age,height,weight,overall,potential we use 3 sigma rule
# - From the boxplot we can see that the outliers are not > 5% so we can use mean imputation for the outliers

# %%
Data= ['age','height_cm','weight_kg','overall','potential']
for i in Data: 
    upper_limit = fifa[i].mean() + 3*fifa[i].std()
    lower_limit = fifa[i].mean() - 3*fifa[i].std()
    fifa.loc[fifa[i] > upper_limit,i]=fifa[i].mean()
    fifa.loc[fifa[i] < lower_limit,i]=fifa[i].mean()

# %% [markdown]
# ##### IQR for positively skewed curve
# - For 'value_eur','wage_eur','release_clause_eur' we use IQR

# %%
from scipy import stats
Data=['value_eur','wage_eur','release_clause_eur']
for i in Data:
    iqr = stats.iqr(fifa[i])
    Q1 = fifa[i].quantile(0.25)  # first quantile
    Q3 = fifa[i].quantile(0.75)  #third quantile
    # getting max & min limit
    min_limit = Q1 - 1.5*iqr
    max_limit = Q3 + 1.5*iqr
    # get the percentage
    print('percentage of outliers for ',i,':',len(fifa.loc[fifa[i] > max_limit])/18278*100)
# Out:
# percentage of outliers for  value_eur : 13.737826895721634
# percentage of outliers for  wage_eur : 12.911697122223437
# percentage of outliers for  release_clause_eur : 15.368202210307475

# %% [markdown]
# - since the outliers for 'value_eur','wage_eur','release_clause_eur' are greater than 5% we cannot use imputation on the outliers

# %% [markdown]
# ### Finding correlated columns and dropping
# - Dropping highly correlated columns reduces the dimensionality of the dataset, making clustering algorithms faster and more computationally efficient.
# - It simplifies the model and enhances its interpretability without sacrificing the overall clustering performance.
# -  Highly correlated columns provide redundant information, leading to a duplication of data.

# %%
corr = fifa.corr().abs()
corr_unstacked = corr.unstack()
# Sort the correlations in descending order
sorted_corr = corr_unstacked.sort_values(ascending=False)
highly_corr_features = sorted_corr[(sorted_corr >= 0.97) & (sorted_corr < 1)]
corr_df = pd.DataFrame(highly_corr_features, columns=['corr']).reset_index()
corr_df.columns = ['feature1', 'feature2', 'corr']
print(corr_df)
# Out:
#                      feature1                   feature2      corr
# 0                   dribbling            skill_dribbling  0.989249
# 1             skill_dribbling                  dribbling  0.989249
# 2   defending_standing_tackle                  defending  0.980999
# 3                   defending  defending_standing_tackle  0.980999
# 4                   value_eur         release_clause_eur  0.979233
# 5          release_clause_eur                  value_eur  0.979233
# 6                 Midfielders                    passing  0.976732
# 7                     passing                Midfielders  0.976732
# 8   defending_standing_tackle   defending_sliding_tackle  0.975808
# 9    defending_sliding_tackle  defending_standing_tackle  0.975808
# 10                   shooting        attacking_finishing  0.973978
# 11        attacking_finishing                   shooting  0.973978
# 12         goalkeeping_diving       goalkeeping_reflexes  0.973922
# ...

# %%
fifa.drop(['skill_dribbling','release_clause_eur','defending_standing_tackle','Midfielders','goalkeeping_handling',
           'goalkeeping_positioning','goalkeeping_reflexes','attacking_finishing'],axis=1,inplace=True)

# %%
len(fifa.columns)
# Out:
# 50

# %% [markdown]
# ### Scaling the data

# %%
s=MinMaxScaler()
al=s.fit_transform(fifa)
a=pd.DataFrame(al,columns=['age', 'height_cm', 'weight_kg', 'overall', 'potential', 'value_eur',
       'wage_eur', 'player_positions', 'preferred_foot',
       'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
       'body_type', 'pace', 'shooting', 'passing', 'dribbling', 'defending',
       'physic', 'attacking_crossing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_curve',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking', 'defending_sliding_tackle',
       'goalkeeping_diving', 'goalkeeping_kicking', 'Attackers', 'Defenders'])
a.head()
# Out:
#         age  height_cm  weight_kg  overall  potential  value_eur  wage_eur  \
# 0  0.695652   0.205128   0.414634  0.46782    0.50134   0.905213  1.000000
# 1  0.782609   0.641026   0.682927  0.46782    0.50134   0.554502  0.716814
# 2  0.478261   0.333333   0.317073  0.46782    0.50134   1.000000  0.513274
# 3  0.434783   0.666667   0.780488  0.46782    0.50134   0.734597  0.221239
# 4  0.521739   0.333333   0.463415  0.46782    0.50134   0.853081  0.831858
#
#    player_positions  preferred_foot  international_reputation  weak_foot  \
# 0          0.214286             0.0                      1.00       0.75
# 1          0.071429             1.0                      1.00       0.75
# 2          0.142857             1.0                      1.00       1.00
# 3          1.000000             1.0                      0.50       0.50
# 4          0.142857             1.0                      0.75       0.75
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() # Object Creation
fifa[['age','height_cm','weight_kg','overall','potential','value_eur','wage_eur',
    'pace','shooting','passing','dribbling','defending','physic','attacking_crossing','attacking_crossing',
    'attacking_heading_accuracy','attacking_short_passing','attacking_volleys',
    'skill_curve','skill_fk_accuracy','skill_fk_accuracy','skill_long_passing',
    'skill_ball_control','skill_ball_control','movement_acceleration','movement_sprint_speed',
    'movement_agility','movement_reactions','movement_balance','power_shot_power','power_jumping',
    'power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions',
    'mentality_positioning','mentality_vision','mentality_penalties','mentality_composure','defending_marking',
    'defending_sliding_tackle','goalkeeping_diving',
    'goalkeeping_kicking','Attackers','Defenders']]=scaler.fit_transform(fifa[['age','height_cm','weight_kg','overall','potential','value_eur','wage_eur',
    'pace','shooting','passing','dribbling','defending','physic','attacking_crossing','attacking_crossing',
    'attacking_heading_accuracy','attacking_short_passing','attacking_volleys',
    'skill_curve','skill_fk_accuracy','skill_fk_accuracy','skill_long_passing',
    'skill_ball_control','skill_ball_control','movement_acceleration','movement_sprint_speed',
    'movement_agility','movement_reactions','movement_balance','power_shot_power','power_jumping',
    'power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions',
    'mentality_positioning','mentality_vision','mentality_penalties','mentality_composure','defending_marking',
    'defending_sliding_tackle','goalkeeping_diving',
    'goalkeeping_kicking','Attackers','Defenders']])

# %%
fifa.head()
# Out:
#         age  height_cm  weight_kg  overall  potential  value_eur  wage_eur  \
# 0  0.695652   0.205128   0.414634  0.46782    0.50134   0.905213  1.000000
# 1  0.782609   0.641026   0.682927  0.46782    0.50134   0.554502  0.716814
# 2  0.478261   0.333333   0.317073  0.46782    0.50134   1.000000  0.513274
# 3  0.434783   0.666667   0.780488  0.46782    0.50134   0.734597  0.221239
# 4  0.521739   0.333333   0.463415  0.46782    0.50134   0.853081  0.831858
#
#    player_positions  preferred_foot  international_reputation  weak_foot  \
# 0                 3               0                         5          4
# 1                 1               1                         5          4
# 2                 2               1                         5          5
# 3                14               1                         3          3
# 4                 2               1                         4          4
#
# ...

# %% [markdown]
# ### PRINCIPLE COMPONENT ANALYSIS(PCA)
# - PCA (Principal Component Analysis) is a widely used technique that simplifies complex datasets by reducing the number of features or variables while retaining essential information.
# - It achieves this by transforming the original features into a new set of orthogonal principal components.

# %%
from sklearn.decomposition import PCA
pca = PCA()
principlecomponents = pca.fit_transform(fifa) # Fitting the data
plt.figure(figsize=(10,7))
sns.set_style('darkgrid')
plt.plot(np.cumsum(pca.explained_variance_ratio_),marker='+',color='g') #plot the variance ratio
plt.xlabel('Number of components')
plt.ylabel('Variance(%)')
plt.title('Explained Variance')
plt.show()

# %% [markdown]
# - Here we take 20 principle components which can explain 96 % of varience in the data.

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.87693318, 0.91852736, 0.93434962, 0.94895331, 0.95986286,
#        0.9673902 , 0.97475186, 0.98131574, 0.98492945, 0.98778742,
#        0.98971907, 0.99146943, 0.99272777, 0.99355626, 0.99415435,
#        0.99465711, 0.99514555, 0.99555282, 0.99593813, 0.99628447,
#        0.99660896, 0.99690385, 0.99716211, 0.99741123, 0.99763284,
#        0.99785405, 0.99805773, 0.99825153, 0.99843401, 0.99861008,
#        0.99878036, 0.9989383 , 0.99908493, 0.99922044, 0.99934503,
#        0.99945599, 0.99954324, 0.99962098, 0.99969344, 0.99975976,
#        0.99982039, 0.99986894, 0.99990545, 0.99993359, 0.99995568,
#        0.9999736 , 0.99998546, 0.99999544, 0.99999934, 1.        ])

# %%
from sklearn.decomposition import PCA
pca = PCA()
principlecomponents = pca.fit_transform(a) # Fitting the data
plt.figure(figsize=(10,7))
sns.set_style('darkgrid')
plt.plot(np.cumsum(pca.explained_variance_ratio_),marker='+',color='g') #plot the variance ratio
plt.xlabel('Number of components')
plt.ylabel('Variance(%)')
plt.title('Explained Variance')
plt.show()

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.43177541, 0.59248962, 0.67956069, 0.73777431, 0.77940505,
#        0.81968075, 0.84832492, 0.87054566, 0.88912688, 0.90023714,
#        0.91099936, 0.9187266 , 0.9259834 , 0.93187304, 0.93711172,
#        0.94174128, 0.94612372, 0.95047557, 0.95445445, 0.9581494 ,
#        0.96160678, 0.96471649, 0.96761626, 0.97044247, 0.97296854,
#        0.97546748, 0.97780384, 0.98003329, 0.98212607, 0.98414519,
#        0.98609172, 0.98789782, 0.98957531, 0.99112269, 0.99255586,
#        0.99382898, 0.99483255, 0.99572145, 0.99655467, 0.99728548,
#        0.99793404, 0.99849267, 0.9989122 , 0.99923586, 0.99949007,
#        0.99969633, 0.99983273, 0.99994756, 0.99999235, 1.        ])

# %%
pca = PCA(n_components=5)
f = pca.fit_transform(fifa)

principle_df = pd.DataFrame(data=f,columns=['pca1','pca2','pca3','pca3','pca3'])
principle_df.head()
# Out:
#        pca1      pca2      pca3      pca3      pca3
# 0  5.516444  2.106850 -0.823292 -0.290826 -0.163787
# 1  7.600670  2.311950 -0.938460 -0.229442 -0.759651
# 2  6.664810  2.621725 -1.745891  0.359035 -0.901376
# 3 -6.110560 -1.227908 -1.063904  0.118526 -0.364188
# 4  6.510323  1.759372 -0.972794 -0.114198 -0.724881

# %%
pca = PCA(n_components=20)
f = pca.fit_transform(a)

principle_a = pd.DataFrame(data=f,columns=['pca1','pca2','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3','pca3'])
principle_a.head()
# Out:
#        pca1      pca2      pca3      pca3      pca3      pca3      pca3  \
# 0 -1.995938 -0.795737  0.574126  0.797160 -0.130990 -0.392819  0.424490
# 1 -1.888507 -0.859410 -0.511737  0.882763 -0.120115 -0.035514 -0.314181
# 2 -1.836158 -1.108315 -0.313044  0.395701 -0.212808 -0.629227  0.025369
# 3  1.971448 -0.130802 -0.199816  0.655668 -0.025064 -0.637774 -0.242295
# 4 -1.765924 -0.954916 -0.332628  0.399985 -0.212634 -0.464533 -0.053592
#
#        pca3      pca3      pca3      pca3      pca3      pca3      pca3  \
# 0 -0.149924 -0.360380  0.078507  0.119009 -0.026571  0.215809 -0.247167
# 1 -0.015922 -0.305178  0.113534  0.087050  0.051803  0.345395 -0.383923
# 2 -0.108963 -0.023254  0.133065  0.322912 -0.111085  0.341429 -0.222684
# 3 -0.326306 -0.383208 -0.077699  0.050168  0.002600 -0.279790 -0.173083
# 4 -0.063082 -0.057378  0.167747  0.077143 -0.144062  0.148595 -0.155183
#
#        pca3      pca3      pca3      pca3      pca3      pca3
# ...

# %% [markdown]
# ### 1. KMEANS Clustering

# %%
from sklearn.cluster import KMeans
kmeans = KMeans() # Object creation
wcss = [] # Create empty list

for i in range(2,10):
    kmeans = KMeans(n_clusters=i,random_state=4)
    kmeans = kmeans.fit(principle_df)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(14,10))
plt.plot(range(2,10),wcss,marker='*')
plt.title('The Elbow Method',fontsize=20)
plt.xlabel('Number of clusters',fontsize=20)
plt.ylabel('WCSS',fontsize=20)
plt.show()

# %% [markdown]
# ### Importing the required model evaluation matrix:
# - The silhouette score, davies_bouldin_score,calinski_harabasz_score are the clustering evaluation metric used to assess the quality of clustering results.
# - Silhouette Score: It measures how well each data point belongs to its cluster compared to other clusters. A higher score means the clusters are well-defined and not too close to each other.
# - Davies-Bouldin Score: It assesses clustering by looking at how compact each cluster is and how separated they are from each other. A lower score suggests clear and separate clusters without much overlap.
# - Calinski-Harabasz Score: It evaluates clustering by comparing how far the clusters are from each other to how far the points are within the clusters. A higher score means the clusters are well-defined and distinct from each other

# %%
from sklearn.metrics import silhouette_score,davies_bouldin_score,calinski_harabasz_score

# %%
kmeans = KMeans(n_clusters=4,random_state=4)
kmeans.fit(principle_df)
Kmeans_silhou_4 = silhouette_score(principle_df,kmeans.labels_)
Kmeans_davies_4 = davies_bouldin_score(principle_df,kmeans.labels_)
Kmeans_calinski_4 = calinski_harabasz_score(principle_df,kmeans.labels_)
print("Silhouette Score:",Kmeans_silhou_4)
print('davies_score:',Kmeans_davies_4)
print('calinski:',Kmeans_calinski_4)
# Out:
# Silhouette Score: 0.5017804225824166
# davies_score: 0.6938207364479254
# calinski: 50884.82108692161

# %%
kmeans = KMeans(n_clusters=3,random_state=4)
kmeans.fit(principle_df)
Kmeans_silhou_3 = silhouette_score(principle_df,kmeans.labels_)
Kmeans_davies_3 = davies_bouldin_score(principle_df,kmeans.labels_)
Kmeans_calinski_3 = calinski_harabasz_score(principle_df,kmeans.labels_)
print("Silhouette Score:",Kmeans_silhou_3)
print('davies_score:',Kmeans_davies_3)
print('calinski:',Kmeans_calinski_3)
# Out:
# Silhouette Score: 0.55007296922825
# davies_score: 0.6393879135830852
# calinski: 54654.420452394734

# %%
kmeans = KMeans(n_clusters=2,random_state=4)
kmeans.fit(principle_df)
Kmeans_silhou_2 = silhouette_score(principle_df,kmeans.labels_)
Kmeans_davies_2 = davies_bouldin_score(principle_df,kmeans.labels_)
Kmeans_calinski_2 = calinski_harabasz_score(principle_df,kmeans.labels_)
print("Silhouette Score:",Kmeans_silhou_2)
print('davies_score:',Kmeans_davies_2)
print('calinski:',Kmeans_calinski_2)
# Out:
# Silhouette Score: 0.6021840344380266
# davies_score: 0.5545960058741337
# calinski: 46586.62519336914

# %% [markdown]
# ### 2. DBSCAN (Density-Based Spatial Clustering of Applications with Noise)

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps=0.96, min_samples=7).fit(principle_df)
labels = db.labels_
n_clusters_ = len(set(labels)) - 1
n_noise_ = list(labels).count(-1)
DB_silhou_4=silhouette_score(principle_df, labels)
DB_davies_4=davies_bouldin_score(principle_df, labels)
DB_calinski_4=calinski_harabasz_score(principle_df, labels)
print("Silhouette score:",DB_silhou_4)
print('davies_score:',DB_davies_4)
print('calinski:',DB_calinski_4)
print("Estimated number of clusters:", n_clusters_)
print("Estimated number of noise points:", n_noise_)
# Out:
# Silhouette score: 0.23105497921275758
# davies_score: 1.9917181644411077
# calinski: 13672.64969400386
# Estimated number of clusters: 4
# Estimated number of noise points: 113

# %%
db = DBSCAN(eps=0.95, min_samples=7).fit(principle_df)
labels = db.labels_
n_clusters_ = len(set(labels)) - 1
n_noise_ = list(labels).count(-1)
DB_silhou_6=silhouette_score(principle_df, labels)
DB_davies_6=davies_bouldin_score(principle_df, labels)
DB_calinski_6=calinski_harabasz_score(principle_df, labels)
print("Silhouette score:",DB_silhou_6)
print('davies_score:',DB_davies_6)
print('calinski:',DB_calinski_6)
print("Estimated number of clusters:", n_clusters_)
print("Estimated number of noise points:", n_noise_)
# Out:
# Silhouette score: 0.17620250717048036
# davies_score: 1.8579911462900771
# calinski: 9320.975531461463
# Estimated number of clusters: 6
# Estimated number of noise points: 130

# %% [markdown]
# ### 3. Hierarchical Clustering

# %%
from sklearn.cluster import AgglomerativeClustering  
hc = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward') 
labels = hc.fit_predict(principle_df)
H_silhou_2=silhouette_score(principle_df, labels)
H_davies_2=davies_bouldin_score(principle_df, labels)
H_calinski_2=calinski_harabasz_score(principle_df, labels)
print("Silhouette score:",H_silhou_2)
print('davies_score:',H_davies_2)
print('calinski:',H_calinski_2)
# Out:
# Silhouette score: 0.5997854969471553
# davies_score: 0.5538956995190704
# calinski: 45614.875875579615

# %%
hc = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward') 
labels = hc.fit_predict(principle_df)
H_silhou_3=silhouette_score(principle_df, labels)
H_davies_3=davies_bouldin_score(principle_df, labels)
H_calinski_3=calinski_harabasz_score(principle_df, labels)
print("Silhouette score:",H_silhou_3)
print('davies_score:',H_davies_3)
print('calinski:',H_calinski_3)
# Out:
# Silhouette score: 0.5616047050340713
# davies_score: 0.5963423497599429
# calinski: 52522.28846473387

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward') 
labels = hc.fit_predict(principle_df)
H_silhou_4=silhouette_score(principle_df, labels)
H_davies_4=davies_bouldin_score(principle_df, labels)
H_calinski_4=calinski_harabasz_score(principle_df, labels)
print("Silhouette score:",H_silhou_4)
print('davies_score:',H_davies_4)
print('calinski:',H_calinski_4)
# Out:
# Silhouette score: 0.4979456611407955
# davies_score: 0.660658978385511
# calinski: 48121.64871791806

# %%
import scipy.cluster.hierarchy as h
plt.figure(figsize=(15,5))
dendrogram = h.dendrogram(h.linkage(principle_df, method="ward"))  # linkage: It defines the linkage criteria
plt.title("Dendrogram Plot")  
plt.ylabel("Euclidean Distances")  
plt.xlabel("Players")  
plt.show()

# %% [markdown]
# ### Model Comparison report
#
# 1.KMEANS Clustering:
#
#  - For the number of clusters=2:
#
#     - Silhouette Score: 0.6021
#     - Davies-Bouldin Score: 0.5545
#     - Calinski-Harabasz Score: 46586.6251
#     - Clustering seems to be effective with two clusters, as indicated by a relatively high Silhouette Score and Calinski-Harabasz Score. Davies-Bouldin Score suggests reasonable separation and compactness.
#
#  - For the number of clusters=3:
#
#    - Silhouette Score: 0.5500
#    - Davies-Bouldin Score: 0.6393
#    - Calinski-Harabasz Score: 54654.4204
#    - Clustering with three clusters shows good Silhouette and Calinski-Harabasz Scores, indicating well-defined and dispersed clusters. The Davies-Bouldin Score suggests even better separation.
#
#  - For the number of clusters=4:
#
#    - Silhouette Score: 0.5017
#    - Davies-Bouldin Score: 0.6938
#    - Calinski-Harabasz Score: 50884.8210
#    - With four clusters, the Silhouette Score decreases slightly, and the Davies-Bouldin Score increases, indicating less distinct clusters compared to three clusters.
#
# - Overall, three clusters seem to provide a good balance between well-defined clusters and reasonable separation, as evidenced by higher Silhouette and Calinski-Harabasz Scores, and a relatively low Davies-Bouldin Score compared to other cluster numbers.
#
#
#
#
# 2.DBSCAN:
#
#  - For epsilon (e) = 0.096 and min_samples = 7:
#
#    - Silhouette Score: 0.23105497921275758
#    - Davies-Bouldin Score: 1.9917181644411077
#    - Calinski-Harabasz Score: 13672.64969400386
#    - Estimated number of clusters: 4
#    - Estimated number of noise points: 113
#    - Clustering with these parameters yields 4 well-defined clusters, as indicated by the Silhouette Score and Calinski-Harabasz Score. The Davies-Bouldin Score suggests some overlap between clusters but overall reasonable separation.
#
#  - For epsilon (e) = 0.095 and min_samples = 7:
#
#    - Silhouette Score: 0.1762
#    - Davies-Bouldin Score: 1.8579
#    - Calinski-Harabasz Score: 9320.9755
#    - Estimated number of clusters: 6
#    - Estimated number of noise points: 130
#    - Clustering with slightly lower epsilon and the same min_samples results in 6 clusters. The Silhouette Score decreases, indicating less well-defined clusters, and the Davies-Bouldin Score improves, suggesting better separation.
#
# - the lower value of DBSCAN's Davies-Bouldin Score is often a result of having clusters with low-density data points.
# - DBSCAN is designed to identify clusters in regions of high-density,
# - and when the clusters are sparse or widely dispersed,
# - the Davies-Bouldin Score increases due to the lack of compactness and clear separation between the clusters
#
#
# 3.Hierarchical Clustering
#
#  - For n_clusters=2, affinity='euclidean', linkage='ward':
#
#    - Silhouette Score: 0.5997
#    - Davies-Bouldin Score: 0.5538
#    - Calinski-Harabasz Score: 45614.8758
#    - Clustering with 2 clusters shows good Silhouette Score and Calinski-Harabasz Score, indicating well-separated and compact clusters.
#
#  - For n_clusters=3, affinity='euclidean', linkage='ward':
#
#    - Silhouette Score: 0.5616
#    - Davies-Bouldin Score: 0.5963
#    - Calinski-Harabasz Score: 52522.2884
#    - Clustering with 3 clusters exhibits decent Silhouette Score and Calinski-Harabasz Score, suggesting reasonably separated clusters.
#
#  - For n_clusters=4, affinity='euclidean', linkage='ward':
#
#    - Silhouette Score: 0.4979
#    - Davies-Bouldin Score: 0.6606
#    - Calinski-Harabasz Score: 48121.6487
#    - Clustering with 4 clusters shows a lower Silhouette Score and higher Davies-Bouldin Score, implying less distinct and slightly more overlapped clusters compared to previous configurations.
#
# - Observation from Hierarchical Clustering :
#   - The number of clusters impacts clustering quality in hierarchical clustering.
#   - As the number of clusters increases, the Silhouette Score tends to decrease, indicating less well-defined clusters.
#   - The Davies-Bouldin Score increases, suggesting more overlap between clusters.
#   - The Calinski-Harabasz Score might fluctuate but can help identify an optimal number of clusters.

# %%
data = pd.DataFrame({
    'Models': ['kmean_2C', 'kmean_3C', 'Kmean_4C', 'DB_4C', 'DB_6C'],
    'Silhouette_score': [Kmeans_silhou_2,Kmeans_silhou_3,Kmeans_silhou_4,DB_silhou_4,DB_silhou_6]
})

# Sort the DataFrame by the values in descending order
data_sorted = data.sort_values('Silhouette_score', ascending=False)
plt.figure(figsize=(13, 6))
ax=sns.barplot(x='Silhouette_score', y='Models', data=data_sorted, palette='viridis')
plt.xlabel('Silhouette_score')
plt.ylabel('Models')
plt.title('performance of each model (Silhouette_score)')
# Add value annotations to the bars
for i, value in enumerate(data_sorted['Silhouette_score']):
    ax.text(value + 0.01, i, str(round(value,4)), va='center')
plt.show()

# %% [markdown]
# ### Best Model for production
# - It is important to strike a balance between data-driven clustering metrics and domain knowledge when choosing the optimal number of clusters, ensuring that the clustering results make sense in the context of the problem being addressed.
# - KMeans with number of clusters=2 performs well with a silhouette score of 0.6, suggesting distinct clusters,
# - this is because the data of goalkeeper position is entirely different from other positions, so it clasiifies goalkeeper as one cluster and rest of the players as other cluster.
# - Based on domain knowledge, players are commonly classified into 4 groups: attackers, midfielders, defenders, and goalkeepers.
# - Therefore, it is more appropriate to choose KMeans with number of clusters=4 as the optimal model.
# - It achieves a silhouette score of 0.50, which indicates reasonable clustering and aligns with the meaningful player position classifications.

# %% [markdown]
# ### Report on Challenges faced
# 1.Missing Data:
# - Technique: Imputation
# - Reason: For attributes with missing data, imputation techniques like mean, median,min are used to fill in the missing values, ensuring the integrity of the dataset for clustering.
#
# 2.High Dimensionality:
# - Technique: Dimensionality Reduction
# - Reason: To handle high-dimensional data, techniques like Principal Component Analysis (PCA) is applied to reduce the number of attributes while preserving most of the variance.
#
# 3.Data Preprocessing:
# - Technique: Labelencoding
# - Reason: The categorical attributes are manually labelencoded to converts them into numerical form suitable for clustering.
#
# 4.Outliers:
# - Technique: Z-score,IQR
# - Reason:
# - Outliers can distort clustering results
# - techniques like Z-score or IQR (Interquartile Range) are used to detect the outliers.
#
#
# 5.Correlation:
# - Highly correlation features are found using fifa.corr() function and features with correlation >=97 are dropped.
#
#
# 6.Varying Data Scales:
# - Technique: Minmaxsaclar
# - Reason:
# - Here MinMaxScaler scalar is used to sacle the data,
# - Scaling attributes to a similar range prevents certain features from dominating the clustering process, ensuring a fair representation of all attributes.
#
#
# 7.Interpreting Clusters:
# - Technique: Domain Knowledge
# - Reason: Domain knowledge is used to find the optimal number of cluster for fifa 20 dataset.
#
# 8.Determining Optimal Clustering Algorithm:
# - Technique: Comparison and Evaluation
# - Reason: Trying multiple clustering algorithms (e.g., KMeans, DBSCAN, Hierarchical) and evaluating their performance using metrics like Silhouette Score and Davies-Bouldin Score helps identify the best algorithm for the dataset.
#
#
# By employing these techniques, the challenges faced in the FIFA20 dataset are effectively addressed, leading to meaningful clustering results that offer valuable insights into player skills and position classifications.
